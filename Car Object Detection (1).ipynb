# %%
# !pip install ultralytics
# !pip install ultralytics opencv-python
# !pip install tensorflow-cpu
# Out:
# Requirement already satisfied: ultralytics in c:\users\sulta\anaconda3\lib\site-packages (8.4.101)
# Requirement already satisfied: filelock>=3.16.1 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (3.20.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (2.3.5)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (3.10.6)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.6.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (5.0.0.93)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: torch>=1.8.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (2.13.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (0.28.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (1.42.1)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (2.0.20)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.42.1 in c:\users\sulta\anaconda3\lib\site-packages (from polars>=0.20.0->ultralytics) (1.42.1)
# Requirement already satisfied: six>=1.5 in c:\users\sulta\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sulta\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sulta\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sulta\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sulta\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sulta\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\sulta\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sulta\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\sulta\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in c:\users\sulta\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\sulta\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sulta\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sulta\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: ultralytics in c:\users\sulta\anaconda3\lib\site-packages (8.4.101)
# Requirement already satisfied: opencv-python in c:\users\sulta\anaconda3\lib\site-packages (5.0.0.93)
# Requirement already satisfied: filelock>=3.16.1 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (3.20.0)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (2.3.5)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (3.10.6)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (12.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: torch>=1.8.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (2.13.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (0.28.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (1.42.1)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\sulta\anaconda3\lib\site-packages (from ultralytics) (2.0.20)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sulta\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.42.1 in c:\users\sulta\anaconda3\lib\site-packages (from polars>=0.20.0->ultralytics) (1.42.1)
# Requirement already satisfied: six>=1.5 in c:\users\sulta\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sulta\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sulta\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sulta\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sulta\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.6.17)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sulta\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\sulta\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sulta\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\sulta\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in c:\users\sulta\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\sulta\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sulta\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sulta\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: tensorflow-cpu in c:\users\sulta\anaconda3\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (3.4.0)
# Requirement already satisfied: packaging in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (1.82.1)
# Requirement already satisfied: keras>=3.12.0 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (3.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (2.3.5)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\sulta\anaconda3\lib\site-packages (from tensorflow-cpu) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sulta\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-cpu) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sulta\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-cpu) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sulta\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-cpu) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sulta\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-cpu) (2026.6.17)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sulta\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-cpu) (0.45.1)
# Requirement already satisfied: rich in c:\users\sulta\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow-cpu) (14.2.0)
# Requirement already satisfied: namex in c:\users\sulta\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow-cpu) (0.1.0)
# Requirement already satisfied: optree in c:\users\sulta\anaconda3\lib\site-packages (from keras>=3.12.0->tensorflow-cpu) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sulta\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow-cpu) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sulta\anaconda3\lib\site-packages (from rich->keras>=3.12.0->tensorflow-cpu) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sulta\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow-cpu) (0.1.2)

# %%
# Data Manipulation
import numpy as np
import pandas as pd

# Visualization/Image Processing
import cv2
import matplotlib.pyplot as plt

# Machine Learning
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Input, BatchNormalization, Flatten, MaxPool2D, Dense

# Other
from pathlib import Path

# %%
from pathlib import Path
print(train_path)
print(train_path.exists())
# Out:
# ..\input\car-object-detection\data\training_images
# False

# %%
train_path = Path("../input/car-object-detection/data/training_images")
test_path = Path("../input/car-object-detection/data/testing_images")

# %%
train = pd.read_csv(r'C:\Users\sulta\Downloads\data\train_solution_bounding_boxes (1).csv')
train[['xmin', 'ymin', 'xmax', 'ymax']] = train[['xmin', 'ymin', 'xmax', 'ymax']].astype(int)
train.drop_duplicates(subset='image', inplace=True, ignore_index=True)

# %%
def display_image(img, bbox_coords=[], pred_coords=[], norm=False):
    # if the image has been normalized, scale it up
    if norm:
        img *= 255.
        img = img.astype(np.uint8)
    
    # Draw the bounding boxes
    if len(bbox_coords) == 4:
        xmin, ymin, xmax, ymax = bbox_coords
        img = cv2.rectangle(img, (int(xmin), int(ymin)), (int(xmax), int(ymax)), (0, 255, 0), 3)
        
    if len(pred_coords) == 4:
        xmin, ymin, xmax, ymax = pred_coords
        img = cv2.rectangle(img, (int(xmin), int(ymin)), (int(xmax), int(ymax)), (255, 0, 0), 3)
        
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    
def display_image_from_file(name, bbox_coords=[], path=train_path):
    img = cv2.imread(str(path/name))
    display_image(img, bbox_coords=bbox_coords)
    
def display_from_dataframe(row, path=train_path):
    display_image_from_file(row['image'], bbox_coords=(row.xmin, row.ymin, row.xmax, row.ymax), path=path)
    

def display_grid(df=train, n_items=3):
    plt.figure(figsize=(20, 10))
    
    # get 3 random entries and plot them in a 1x3 grid
    rand_indices = [np.random.randint(0, df.shape[0]) for _ in range(n_items)]
    
    for pos, index in enumerate(rand_indices):
        plt.subplot(1, n_items, pos + 1)
        display_from_dataframe(df.loc[index, :])

# %%
import os
for root, dirs, files in os.walk(r"C:\Users\sulta"):
    for d in dirs:
        if 'training_images' in d.lower() or 'car-object-detection' in d.lower():
            print(os.path.join(root, d))
# Out:
# C:\Users\sulta\data\training_images
# C:\Users\sulta\Downloads\data\training_images

# %%
from pathlib import Path
train_path = Path(r"C:\Users\sulta\data\training_images")
print(train_path.exists())
print(os.listdir(train_path)[:10])
# Out:
# True
# ['vid_4_1000.jpg', 'vid_4_10000.jpg', 'vid_4_10020.jpg', 'vid_4_10040.jpg', 'vid_4_10060.jpg', 'vid_4_10080.jpg', 'vid_4_10100.jpg', 'vid_4_10120.jpg', 'vid_4_10140.jpg', 'vid_4_10160.jpg']

# %%
def display_image_from_file(name, bbox_coords=[], path=None):
    if path is None:
        path = train_path
    img = cv2.imread(str(path/name))
    display_image(img, bbox_coords=bbox_coords)

# %%
display_image_from_file("vid_4_1000.jpg")

# %%
def display_from_dataframe(row, path=None):
    if path is None:
        path = train_path
    display_image_from_file(row['image'], bbox_coords=(row.xmin, row.ymin, row.xmax, row.ymax), path=path)

# %%
def data_generator(df=train, batch_size=16, path=None):
    while True:        
        if path is None:
            path = train_path
        
        images = np.zeros((batch_size, 380, 676, 3))
        bounding_box_coords = np.zeros((batch_size, 4))
        
        for i in range(batch_size):
                rand_index = np.random.randint(0, train.shape[0])
                row = df.loc[rand_index, :]
                images[i] = cv2.imread(str(path/row.image)) / 255.
                bounding_box_coords[i] = np.array([row.xmin, row.ymin, row.xmax, row.ymax])
                
        yield {'image': images}, {'coords': bounding_box_coords}

# %%
display_grid()

# %%
# Test the generator
example, label = next(data_generator(batch_size=1))
img = example['image'][0]
bbox_coords = label['coords'][0]

display_image(img, bbox_coords=bbox_coords, norm=True)

# %%
input_ = Input(shape=[380, 676, 3], name='image')

x = input_

for i in range(10):
    n_filters = 2**(i + 3)
    x = Conv2D(n_filters, 3, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPool2D(2, padding='same')(x)

x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dense(32, activation='relu')(x)
output = Dense(4, name='coords')(x)

model = tf.keras.models.Model(input_, output)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ image (InputLayer)              │ (None, 380, 676, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 380, 676, 8)    │           224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 380, 676, 8)    │            32 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 190, 338, 8)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 190, 338, 16)   │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 190, 338, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 95, 169, 16)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 95, 169, 32)    │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 95, 169, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 48, 85, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 48, 85, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 48, 85, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 24, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 24, 43, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 24, 43, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 12, 22, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 22, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 12, 22, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 6, 11, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 6, 11, 512)     │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 6, 11, 512)     │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 3, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 3, 6, 1024)     │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 3, 6, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 2, 3, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 2, 3, 2048)     │    18,876,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 2, 3, 2048)     │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 1, 2, 2048)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 1, 2, 4096)     │    75,501,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 1, 2, 4096)     │        16,384 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 1, 1, 4096)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,048,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         8,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ coords (Dense)                  │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,761,236 (388.19 MB)
#  Trainable params: 101,744,868 (388.13 MB)
#  Non-trainable params: 16,368 (63.94 KB)

# %%
model.compile(
    loss={
        'coords': 'mse'
    },
    optimizer=tf.keras.optimizers.Adam(1e-3),
    metrics={
        'coords': 'accuracy'
    }
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
# Some functions to test the model. These will be called every epoch to display the current performance of the model
def test_model(model, datagen):
    example, label = next(datagen)
    
    X = example['image']
    y = label['coords']
    
    pred_bbox = model.predict(X)[0]
    
    img = X[0]
    gt_coords = y[0]
    
    display_image(img, pred_coords=pred_bbox, norm=True)

def test(model):
    datagen = data_generator(batch_size=1)
    
    plt.figure(figsize=(15,7))
    for i in range(3):
        plt.subplot(1, 3, i + 1)
        test_model(model, datagen)    
    plt.show()
    
class ShowTestImages(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        test(self.model)

# %%
test(model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 731ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step

# %%
def data_generator(df=train, batch_size=16, path=None):
    while True:        
        if path is None:
            path = train_path
        
        images = np.zeros((batch_size, 380, 676, 3))
        bounding_box_coords = np.zeros((batch_size, 4))
        
        for i in range(batch_size):
                rand_index = np.random.randint(0, train.shape[0])
                row = df.loc[rand_index, :]
                images[i] = cv2.imread(str(path/row.image)) / 255.
                bounding_box_coords[i] = np.array([row.xmin, row.ymin, row.xmax, row.ymax])
                
        yield {'image': images}, {'coords': bounding_box_coords}
